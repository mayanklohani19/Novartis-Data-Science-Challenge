# %% [markdown]
# # Novartis Data Science Challenge
#
# ## By Mayank Lohani

# %% [markdown]
# # Importing the Required Pacakges

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import datetime as dt
# %matplotlib inline
import math
from sklearn.model_selection import train_test_split
from sklearn import metrics

from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Create User Defined Functions

# %%
# Create Data audit Report for continuous variables
def continuous_var_summary(x):
    return pd.Series([
        x.count(),
        x.isnull().sum(),
        x.sum(),
        x.mean(),
        x.median(),
        x.std(),
        x.var(),
        x.min(),
        x.quantile(0.01),
        x.quantile(0.05),
        x.quantile(0.10),
        x.quantile(0.25),
        x.quantile(0.50),
        x.quantile(0.75),
        x.quantile(0.90),
        x.quantile(0.95),
        x.quantile(0.99),
        x.max()
    ],
                     index=[
                         'N', 'NMISS', 'SUM', 'MEAN', 'MEDIAN', 'STD', 'VAR',
                         'MIN', 'P1', 'P5', 'P10', 'P25', 'P50', 'P75', 'P90',
                         'P95', 'P99', 'MAX'
                     ])

# %%
# Create Data audit Report for categorical variables
def categorical_var_summary(x):
    Mode = x.value_counts().sort_values(ascending=False)[0:1].reset_index()
    return pd.Series([
        x.count(),
        x.isnull().sum(), Mode.iloc[0, 0], Mode.iloc[0, 1],
        round(Mode.iloc[0, 1] * 100 / x.count(), 2)
    ],
                     index=['N', 'NMISS', 'MODE', 'FREQ', 'PERCENT'])

# %%
# Missing value imputation for categorical and continuous variables
def missing_imputation(x, stats='mean'):
    if (x.dtypes == 'float64') | (x.dtypes == 'int64'):
        x = x.fillna(x.mean()) if stats == 'mean' else x.fillna(x.median())
    else:
        x = x.fillna(x.mode())
    return x

# %%
#An utility function to create dummy variable
def create_dummies(df, colname):
    col_dummies = pd.get_dummies(df[colname], prefix=colname, drop_first=True)
    df = pd.concat([df, col_dummies], axis=1)
    df.drop(colname, axis=1, inplace=True)
    return df

# %%
# create user defined function to create the freq plots
def fn_countplot(pd_series):
    plt.figure(figsize=(5, 3))
    sns.countplot(y=pd_series)
    print('This is a freq chart for ' + pd_series.name)
    plt.show()
    return

# %% [markdown]
# # Importing the Datasets

# %%
train = pd.read_csv('train.csv')  #Importing the train data

test = pd.read_csv('test.csv')  #Importing the test data

sample_submission = pd.read_csv('sample_submission.csv')  #Importing the sample submission data

# %%
#First 5 elements of the dataset
train.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   174   1.0    92    29    36                 0
# 1   236   1.0   103   142    34                 1
# 2   174   1.0   110    93    34                 1
# 3   249   1.0    72    29    34                 1
# 4   174   0.0   112    29    43                 1

# %%
#Description of the data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
# INCIDENT_ID         23856 non-null object
# DATE                23856 non-null object
# X_1                 23856 non-null int64
# X_2                 23856 non-null int64
# X_3                 23856 non-null int64
# X_4                 23856 non-null int64
# X_5                 23856 non-null int64
# X_6                 23856 non-null int64
# X_7                 23856 non-null int64
# X_8                 23856 non-null int64
# X_9                 23856 non-null int64
# X_10                23856 non-null int64
# X_11                23856 non-null int64
# X_12                23674 non-null float64
# X_13                23856 non-null int64
# X_14                23856 non-null int64
# X_15                23856 non-null int64
# MULTIPLE_OFFENSE    23856 non-null int64
# dtypes: float64(1), int64(15), object(2)
# memory usage: 3.3+ MB

# %%
#Generate descriptive statistics.
train.describe()
# Out:
#                 X_1           X_2           X_3           X_4           X_5  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       0.483778     24.791206     24.637450      4.276744      2.455609
# std        1.439738     15.240231     15.135093      2.944672      1.963095
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      7.000000      8.000000      2.000000      1.000000
# 50%        0.000000     24.000000     24.000000      4.000000      3.000000
# 75%        0.000000     36.000000     35.000000      6.000000      5.000000
# max        7.000000     52.000000     52.000000     10.000000      5.000000
#
#                 X_6           X_7           X_8           X_9          X_10  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       6.154175      4.876509      0.972460      4.924128      1.244802
# std        4.471756      3.881931      1.453144      1.362625      1.119301
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        3.000000      2.000000      0.000000      5.000000      1.000000
# 50%        5.000000      4.000000      1.000000      5.000000      1.000000
# 75%        8.000000      7.000000      1.000000      6.000000      1.000000
# max       19.000000     18.000000     99.000000      6.000000     90.000000
#
#                X_11          X_12          X_13          X_14          X_15  \
# count  23856.000000  23674.000000  23856.000000  23856.000000  23856.000000
# mean     206.954519      0.974064     85.237383     72.674296     33.464747
# std       93.033348      1.167725     27.597226     43.297320      8.386834
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      174.000000      1.000000     72.000000     29.000000     34.000000
# 50%      249.000000      1.000000     98.000000     62.000000     34.000000
# 75%      249.000000      1.000000    103.000000    107.000000     34.000000
# max      332.000000     90.000000    116.000000    142.000000     50.000000
#
#        MULTIPLE_OFFENSE
# count      23856.000000
# mean           0.955231
# std            0.206800
# min            0.000000
# 25%            1.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000

# %%
#First 5 elements of the dataset
test.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# 1   CR_103520  05-MAR-04    0   44   44    1    3    7    1    4    6     1
# 2   CR_196089  27-JAN-18    0   34   33    3    5    2    7    3    0     1
# 3   CR_112195  18-AUG-06    7    3    2    3    5    9    8    0    5     1
# 4   CR_149832  31-OCT-11    0    7    8    7    3    2    7    1    5     1
#
#    X_11  X_12  X_13  X_14  X_15
# 0   174   NaN    72   119    23
# 1   316   0.0    12    29    34
# 2   316   1.0    72     0    34
# 3   174   1.0   112    87    34
# 4   174   0.0   112    93    43

# %%
#Description of the data
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15903 entries, 0 to 15902
# Data columns (total 17 columns):
# INCIDENT_ID    15903 non-null object
# DATE           15903 non-null object
# X_1            15903 non-null int64
# X_2            15903 non-null int64
# X_3            15903 non-null int64
# X_4            15903 non-null int64
# X_5            15903 non-null int64
# X_6            15903 non-null int64
# X_7            15903 non-null int64
# X_8            15903 non-null int64
# X_9            15903 non-null int64
# X_10           15903 non-null int64
# X_11           15903 non-null int64
# X_12           15776 non-null float64
# X_13           15903 non-null int64
# X_14           15903 non-null int64
# X_15           15903 non-null int64
# dtypes: float64(1), int64(14), object(2)
# memory usage: 2.1+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15903 entries, 0 to 15902
# Data columns (total 17 columns):
# INCIDENT_ID    15903 non-null object
# DATE           15903 non-null object
# X_1            15903 non-null int64
# X_2            15903 non-null int64
# X_3            15903 non-null int64
# X_4            15903 non-null int64
# X_5            15903 non-null int64
# X_6            15903 non-null int64
# X_7            15903 non-null int64
# X_8            15903 non-null int64
# X_9            15903 non-null int64
# X_10           15903 non-null int64
# X_11           15903 non-null int64
# X_12           15776 non-null float64
# X_13           15903 non-null int64
# X_14           15903 non-null int64
# X_15           15903 non-null int64
# dtypes: float64(1), int64(14), object(2)
# memory usage: 2.1+ MB

# %%
test.describe()
# Out:
#                 X_1           X_2           X_3           X_4           X_5  \
# count  15903.000000  15903.000000  15903.000000  15903.000000  15903.000000
# mean       0.468088     24.722631     24.575049      4.284223      2.448469
# std        1.412112     15.228841     15.127451      2.974584      1.963372
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      7.000000      8.000000      2.000000      1.000000
# 50%        0.000000     24.000000     24.000000      4.000000      3.000000
# 75%        0.000000     36.000000     35.000000      6.000000      5.000000
# max        7.000000     52.000000     52.000000     10.000000      5.000000
#
#                 X_6           X_7           X_8           X_9          X_10  \
# count  15903.000000  15903.000000  15903.000000  15903.000000  15903.000000
# mean       6.084890      4.862605      0.986732      4.908759      1.241212
# std        4.451117      3.854550      1.471274      1.374677      0.841804
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        3.000000      2.000000      0.000000      5.000000      1.000000
# 50%        5.000000      4.000000      1.000000      5.000000      1.000000
# 75%        8.000000      7.000000      1.000000      6.000000      1.000000
# max       19.000000     18.000000     50.000000      6.000000     40.000000
#
#                X_11          X_12          X_13          X_14          X_15
# count  15903.000000  15776.000000  15903.000000  15903.000000  15903.000000
# mean     206.954097      0.972236     85.191096     72.218575     33.422625
# std       93.107783      0.876669     27.493192     43.438227      8.314284
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      174.000000      1.000000     72.000000     29.000000     34.000000
# 50%      249.000000      1.000000     98.000000     62.000000     34.000000
# 75%      249.000000      1.000000    103.000000    107.000000     34.000000
# max      332.000000     40.000000    117.000000    142.000000     50.000000

# %%
#Separating the categorial and continous variables

train_cont = train.select_dtypes(['int64', 'float64'])
train_cat = train.select_dtypes(['object'])  #The categorical features are not important as they are cardinal.

test_cont = test.select_dtypes(['int64', 'float64'])
test_cat = test.select_dtypes(['object']) #The categorical features are not important as they are cardinal.

# %%
train_cont.apply(continuous_var_summary)   #Descriptive statistics with more features for continous features
# Out:
#                  X_1            X_2            X_3            X_4  \
# N       23856.000000   23856.000000   23856.000000   23856.000000
# NMISS       0.000000       0.000000       0.000000       0.000000
# SUM     11541.000000  591419.000000  587751.000000  102026.000000
# MEAN        0.483778      24.791206      24.637450       4.276744
# MEDIAN      0.000000      24.000000      24.000000       4.000000
# STD         1.439738      15.240231      15.135093       2.944672
# VAR         2.072845     232.264640     229.071025       8.671094
# MIN         0.000000       0.000000       0.000000       0.000000
# P1          0.000000       3.000000       2.000000       0.000000
# P5          0.000000       4.000000       4.000000       0.000000
# P10         0.000000       4.000000       4.000000       0.000000
# P25         0.000000       7.000000       8.000000       2.000000
# P50         0.000000      24.000000      24.000000       4.000000
# P75         0.000000      36.000000      35.000000       6.000000
# P90         1.000000      45.000000      45.000000       9.000000
# P95         3.000000      49.000000      49.000000      10.000000
# P99         7.000000      50.000000      50.000000      10.000000
# MAX         7.000000      52.000000      52.000000      10.000000
#
#                  X_5            X_6            X_7           X_8  \
# N       23856.000000   23856.000000   23856.000000  23856.000000
# NMISS       0.000000       0.000000       0.000000      0.000000
# SUM     58581.000000  146814.000000  116334.000000  23199.000000
# MEAN        2.455609       6.154175       4.876509      0.972460
# MEDIAN      3.000000       5.000000       4.000000      1.000000
# STD         1.963095       4.471756       3.881931      1.453144
# VAR         3.853741      19.996602      15.069386      2.111629
# MIN         0.000000       1.000000       0.000000      0.000000
# P1          0.000000       1.000000       0.000000      0.000000
# P5          0.000000       1.000000       0.000000      0.000000
# P10         0.000000       1.000000       0.000000      0.000000
# P25         1.000000       3.000000       2.000000      0.000000
# P50         3.000000       5.000000       4.000000      1.000000
# P75         5.000000       8.000000       7.000000      1.000000
# P90         5.000000      15.000000      10.000000      2.000000
# P95         5.000000      15.000000      12.000000      3.000000
# P99         5.000000      17.000000      17.000000      5.000000
# MAX         5.000000      19.000000      18.000000     99.000000
#
#                   X_9          X_10          X_11          X_12          X_13  \
# N        23856.000000  23856.000000  2.385600e+04  23674.000000  2.385600e+04
# NMISS        0.000000      0.000000  0.000000e+00    182.000000  0.000000e+00
# SUM     117470.000000  29696.000000  4.937107e+06  23060.000000  2.033423e+06
# MEAN         4.924128      1.244802  2.069545e+02      0.974064  8.523738e+01
# MEDIAN       5.000000      1.000000  2.490000e+02      1.000000  9.800000e+01
# STD          1.362625      1.119301  9.303335e+01      1.167725  2.759723e+01
# VAR          1.856746      1.252834  8.655204e+03      1.363582  7.616069e+02
# MIN          0.000000      1.000000  0.000000e+00      0.000000  0.000000e+00
# P1           1.000000      1.000000  0.000000e+00      0.000000  1.000000e+01
# P5           2.000000      1.000000  0.000000e+00      0.000000  1.800000e+01
# P10          2.000000      1.000000  0.000000e+00      0.000000  3.400000e+01
# P25          5.000000      1.000000  1.740000e+02      1.000000  7.200000e+01
# P50          5.000000      1.000000  2.490000e+02      1.000000  9.800000e+01
# P75          6.000000      1.000000  2.490000e+02      1.000000  1.030000e+02
# P90          6.000000      2.000000  3.160000e+02      2.000000  1.120000e+02
# P95          6.000000      2.000000  3.160000e+02      2.000000  1.120000e+02
# P99          6.000000      4.000000  3.160000e+02      4.000000  1.160000e+02
# MAX          6.000000     90.000000  3.320000e+02     90.000000  1.160000e+02
#
#                 X_14           X_15  MULTIPLE_OFFENSE
# N       2.385600e+04   23856.000000      23856.000000
# NMISS   0.000000e+00       0.000000          0.000000
# SUM     1.733718e+06  798335.000000      22788.000000
# MEAN    7.267430e+01      33.464747          0.955231
# MEDIAN  6.200000e+01      34.000000          1.000000
# STD     4.329732e+01       8.386834          0.206800
# VAR     1.874658e+03      70.338979          0.042766
# MIN     0.000000e+00       0.000000          0.000000
# P1      0.000000e+00       0.000000          0.000000
# P5      2.900000e+01      23.000000          1.000000
# P10     2.900000e+01      34.000000          1.000000
# P25     2.900000e+01      34.000000          1.000000
# P50     6.200000e+01      34.000000          1.000000
# P75     1.070000e+02      34.000000          1.000000
# P90     1.420000e+02      43.000000          1.000000
# P95     1.420000e+02      46.000000          1.000000
# P99     1.420000e+02      48.000000          1.000000
# MAX     1.420000e+02      50.000000          1.000000

# %%
test_cat.apply(categorical_var_summary)  #Descriptive statistics with more features for categorical features
# Out:
#         INCIDENT_ID       DATE
# N             15903      15903
# NMISS             0          0
# MODE      CR_105768  13-SEP-01
# FREQ              1         16
# PERCENT        0.01        0.1

# %% [markdown]
# ### There are some features which have limited null values. Since Categorical values dont have null values).We will treat them with mean/median and mode for continous and categorical features respectively.

# %%
train_cont = train_cont.apply(missing_imputation)

# %%
test_cont = test_cont.apply(missing_imputation)

# %% [markdown]
# ### With the descriptive summary, we can see that we have outliers. We treat outlier data depending on the domain. We will remove outliers in this dataset.

# %%
def outlier_capping(x):
    x = x.clip(upper=x.quantile(0.99))
    x = x.clip(lower=x.quantile(0.01))
    return x


train_cont = train_cont.apply(outlier_capping)
test_cont = test_cont.apply(outlier_capping)

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_1",
              data=train_cont,
              palette="Set3",
              hue='X_1',
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(12, 8))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_2",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(12, 8))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_3",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_4",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_5",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_6",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_7",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_8",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_9",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_10",
              data=train_cont,
              palette="Set3",
               hue = 'X_10',
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(14, 8))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_11",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_12",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(14, 10))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_13",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(20, 14))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_14",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
# Logging parameters distribution
plt.figure(figsize=(6, 4))
plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x="X_15",
              data=train_cont,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

# %% [markdown]
# #### Pairplot - Plot pairwise relationships in a dataset.

# %%
sns.set(style="ticks", color_codes=True)
plt.style.use('ggplot')
sns.pairplot(train_cont, palette="husl", markers="+")
plt.show()

# %% [markdown]
# #### Analysing the y variable. Checking if the y variable is skewed or not.

# %%
#Checking if the y variable is skewed or not

plt.style.use('ggplot')
sns.set(style="darkgrid")
sns.countplot(x='MULTIPLE_OFFENSE',
              hue='MULTIPLE_OFFENSE',
              data=train,
              palette="Set3",
              edgecolor=sns.color_palette("dark", 3))
plt.show()

print(train['MULTIPLE_OFFENSE'].value_counts())
print(train['MULTIPLE_OFFENSE'].value_counts(normalize=True) * 100)

#The y variable is skewed so we need to do sampling of the data.
# Out:
# 1    22788
# 0     1068
# Name: MULTIPLE_OFFENSE, dtype: int64
# 1    95.523139
# 0     4.476861
# Name: MULTIPLE_OFFENSE, dtype: float64

# %%
#Correlation check.
plt.subplots(figsize=(15, 12))
corrm = train.corr()
sns.heatmap(corrm, cmap='viridis', annot=True)

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.triu(np.ones_like(corrm, dtype=np.bool))
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corrm,
            annot=True,
            mask=mask,
            cmap=cmap,
            vmax=.3,
            center=0,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .5})

# %% [markdown]
# #### Saving the correlation matrix in an excel file.

# %%
corrm.to_excel('C:/Users/Mayank/Downloads/Novartis-Data-Science-Challenge/Dataset/corr.xlsx')

# %% [markdown]
# ### We only have 15 features in the Dataset. Therefore we should not work on feature reduction.¶

# %% [markdown]
# ## Final Dataset for applying ML algorithms

# %%
X = train_cont.iloc[:,:-1]
y = train_cont['MULTIPLE_OFFENSE']

# %% [markdown]
# # Building model from statsmodels

# %%
# method 2: divide the data into training and testing for statsmodels.formula.api
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
train, test = train_test_split(train_cont, test_size = 0.3, random_state = 12345)

# %%
# verify the no of obs in training and testing after split
print('No of obs in training: ', len(train), ' | ', 'No of obs in testing: ', len(test))
# Out:
# No of obs in training:  16699  |  No of obs in testing:  7157

# %%
features_final = X.columns
model_param_final = 'MULTIPLE_OFFENSE ~ ' + ' + '.join(features_final)

# %% [markdown]
# ### Bulding a Linear Regression Model for analysis

# %%
lr = smf.logit(formula=model_param_final, data=train).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.125575
#          Iterations 8

# %%
print(lr.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       MULTIPLE_OFFENSE   No. Observations:                16699
# Model:                          Logit   Df Residuals:                    16683
# Method:                           MLE   Df Model:                           15
# Date:                Sat, 20 Jun 2020   Pseudo R-squ.:                  0.3092
# Time:                        11:45:53   Log-Likelihood:                -2097.0
# converged:                       True   LL-Null:                       -3035.7
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.0892      0.333     15.281      0.000       4.437       5.742
# X_1            0.0887      0.041      2.187      0.029       0.009       0.168
# X_2           -0.0248      0.041     -0.607      0.544      -0.105       0.055
# X_3            0.0147      0.041      0.357      0.721      -0.066       0.096
# X_4            0.0132      0.018      0.725      0.469      -0.023       0.049
# X_5           -0.0190      0.027     -0.716      0.474      -0.071       0.033
# X_6            0.0173      0.014      1.209      0.227      -0.011       0.045
# X_7           -0.0138      0.016     -0.845      0.398      -0.046       0.018
# X_8            0.0168      0.041      0.414      0.679      -0.063       0.097
# X_9            0.0209      0.036      0.589      0.556      -0.049       0.091
# X_10          -2.6837      0.084    -31.838      0.000      -2.849      -2.518
# X_11           0.0040      0.000      8.819      0.000       0.003       0.005
# X_12           1.1632      0.068     17.206      0.000       1.031       1.296
# X_13          -0.0019      0.002     -1.172      0.241      -0.005       0.001
# X_14          -0.0016      0.001     -1.493      0.135      -0.004       0.000
# X_15           0.0132      0.004      3.391      0.001       0.006       0.021
# ==============================================================================

# %% [markdown]
# #### We are getting a poor score with Logistic Regression because the data is heavily skewed. Our accuracies will be very misleading. Also, we took all the variables in the dataset. We might have insignificant variables. Let us fix that.¶
#
# #### Let us run a kNN algorithm to see the difference between skewed and balanced data

# %%
# import the packages
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#set the tuning parameters (k) for grid search
tuned_parameters = {
    'n_neighbors': [7, 9, 11, 13, 15,17,19],
   # 'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# build the KNN model
knn_clf = GridSearchCV(KNeighborsClassifier(),
                       tuned_parameters,
                       cv=10,
                       verbose = 10,
                       n_jobs=-1,
                       scoring='roc_auc')

# %%
# model fit
knn_clf.fit(X_train, y_train)
knn_clf.best_score_
# Out:
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:   13.9s finished
# 0.8748026053114011

# %%
metrics.roc_auc_score( y_train, knn_clf.predict_proba( X_train )[:, 1] )
# Out:
# 0.9635682017340074

# %%
knn_clf.best_params_
# Out:
# {'n_neighbors': 19}

# %%
# re-building the model for the best n_neighbors
knn_clf = KNeighborsClassifier( n_neighbors = 19)
knn_clf.fit( X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=19)

# %%
# confusion matrix
knn_cm = metrics.confusion_matrix( y_test, knn_clf.predict( X_test ))

# %%
sns.heatmap(knn_cm, annot=True,  cmap = 'YlGnBu_r',fmt='.2f', xticklabels = ["No", "Yes"] , yticklabels = ["No", "Yes"] )
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 12.5, 'Predicted label')

# %%
# get the model accuracy
print(metrics.accuracy_score(y_train, knn_clf.predict(X_train)))
print(metrics.accuracy_score(y_test, knn_clf.predict(X_test)))
# Out:
# 0.9618344491021711
# 0.956814429061349

# %%
# get the probability score on training and testing
train_predict_prob = pd.DataFrame(knn_clf.predict_proba(X_train))[1]
test_predict_prob = pd.DataFrame(knn_clf.predict_proba(X_test))[1]

# %%
# get the model auc
print(metrics.roc_auc_score(y_train, train_predict_prob))
print(metrics.roc_auc_score(y_test, test_predict_prob))
# Out:
# 0.9635682017340074
# 0.8954855299779722

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y_test, knn_clf.predict( X_test )))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.16      0.25       374
#            1       0.96      1.00      0.98      7499
#
#     accuracy                           0.96      7873
#    macro avg       0.83      0.58      0.62      7873
# weighted avg       0.95      0.96      0.94      7873

# %% [markdown]
# ### Interpretation: We can see from poor precion and recall for '1's in classification report and AUC that model performance is not upto the mark. High accuracy score is misleading because of skewed data.
#
#
# #### We will now rebuild the model after re-balancing the data.
#
# ##### Oversampling & Undersampling for imbalance data

# %%
# import the packages
import imblearn
from imblearn.under_sampling import RandomUnderSampler 
from imblearn.over_sampling import RandomOverSampler 
from imblearn.over_sampling import SMOTE
from collections import Counter

# %% [markdown]
# #### Rebuild model after undersampling

# %%
# perform the under sampling
rus = RandomUnderSampler(random_state = 500)
X_res_train, y_res_train = rus.fit_sample(X_train, y_train)
print('Original dataset shape {}'.format(Counter(y_train)))
print('Oversampled dataset shape {}'.format(Counter(y_res_train)))
# Out:
# Original dataset shape Counter({1: 15289, 0: 694})
# Oversampled dataset shape Counter({0: 694, 1: 694})

# %%
# rebuild the model after resampling
knn_clf = KNeighborsClassifier( n_neighbors = 19 )

# %%
# Refitting the model on under sampled data
knn_clf.fit(X_res_train, y_res_train)
# Out:
# KNeighborsClassifier(n_neighbors=19)

# %%
# get the model accuracy
print(metrics.accuracy_score(y_res_train, knn_clf.predict(X_res_train)))
print(metrics.accuracy_score(y_test, knn_clf.predict(X_test)))
# Out:
# 0.7802593659942363
# 0.7618442779118506

# %%
# get the probability score on training and testing
train_predict_prob = pd.DataFrame(knn_clf.predict_proba(X_res_train))[1]
test_predict_prob = pd.DataFrame(knn_clf.predict_proba(X_test))[1]

# %%
# get the model auc
print(metrics.roc_auc_score(y_res_train, train_predict_prob))
print(metrics.roc_auc_score(y_test, test_predict_prob))
# Out:
# 0.8752616083515353
# 0.8438652782937902

# %% [markdown]
# #### Refit model after oversampling

# %%
# perform the over sampling
ros = RandomOverSampler(random_state = 500)
X_res_train, y_res_train = ros.fit_sample(X_train, y_train)
print('Original dataset shape {}'.format(Counter(y_train)))
print('Oversampled dataset shape {}'.format(Counter(y_res_train)))
# Out:
# Original dataset shape Counter({1: 15289, 0: 694})
# Oversampled dataset shape Counter({1: 15289, 0: 15289})

# %%
# rebuild the model after resampling
knn_clf = KNeighborsClassifier( n_neighbors = 19 )

# %%
# Refitting the model on over sampled data
knn_clf.fit(X_res_train, y_res_train)
# Out:
# KNeighborsClassifier(n_neighbors=19)

# %%
# get the model accuracy
print(metrics.accuracy_score(y_res_train, knn_clf.predict(X_res_train)))
print(metrics.accuracy_score(y_test, knn_clf.predict(X_test)))
# Out:
# 0.9549022172803977
# 0.8919090562682586

# %%
# get the probability score on training and testing
train_predict_prob = pd.DataFrame(knn_clf.predict_proba(X_res_train))[1]
test_predict_prob = pd.DataFrame(knn_clf.predict_proba(X_test))[1]

# %%
# get the model auc
print(metrics.roc_auc_score(y_res_train, train_predict_prob))
print(metrics.roc_auc_score(y_test, test_predict_prob))
# Out:
# 0.9988094468104289
# 0.910974760984174

# %% [markdown]
# #### We will use the oversampled data now for our predictions with a better performing model.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rand = RandomForestClassifier(random_state= 42).fit(X_res_train,y_res_train)

# %%
rand.score(X_res_train,y_res_train)
# Out:
# 1.0

# %%
rand.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_pred1 = pd.DataFrame( { 'actual':  y_test,
                                'predicted': rand.predict( X_test) } )

# %%
y_pred1
# Out:
#        actual  predicted
# 2862        1          1
# 13167       1          1
# 15722       1          1
# 21420       1          1
# 19507       1          1
# ...       ...        ...
# 10406       1          1
# 15431       1          1
# 18883       1          1
# 449         1          1
# 2264        1          1
#
# [7873 rows x 2 columns]

# %%
print(metrics.accuracy_score(y_pred1.actual, y_pred1.predicted))
print(metrics.roc_auc_score(y_pred1.actual, y_pred1.predicted))
# Out:
# 0.9916169185824971
# 0.9460607225348407

# %%
rftree_cm = metrics.confusion_matrix(y_pred1.predicted, y_pred1.actual, [1, 0])
sns.heatmap(rftree_cm,
            annot=True,
            cmap='Set3',
            fmt='.2f',
            )

plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# C:\Users\Mayank\Anaconda3\lib\site-packages\sklearn\utils\validation.py:71: FutureWarning: Pass labels=[1, 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Text(0.5, 12.5, 'Predicted label')

# %%
from sklearn.metrics import recall_score

recall_score(y_test,  rand.predict( X_test))
# Out:
# 0.9963995199359915

# %% [markdown]
#  #### Hypertuning Random Forest to improve the model further

# %%
rfc = RandomForestClassifier(n_jobs=-1,
                             n_estimators=50,
                             oob_score=False,
                             random_state=42)

param_grid = {
    'n_estimators': np.arange(100, 500, 50),
    'max_features': ['auto', 'log2'],
    'max_depth': [15, 25, 30],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [2, 3, 4]
}

CV_rfc = GridSearchCV(estimator=rfc,
                      param_grid=param_grid,
                      cv=5,
                      verbose=10,
                      n_jobs=-1)
CV_rfc.fit(X_res_train, y_res_train)
print(CV_rfc.best_params_)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 23.1min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 27.2min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 28.7min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 31.8min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 33.4min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 35.0min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 36.7min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 38.3min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 40.0min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 41.7min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 43.5min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 45.6min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 47.5min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 49.3min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 51.2min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 53.5min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 55.3min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 57.4min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 59.7min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 61.7min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 64.0min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 66.1min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 68.5min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 70.7min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 73.2min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 75.6min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 78.2min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 80.5min
# [Parallel(n_jobs=-1)]: Done 2160 out of 2160 | elapsed: 82.8min finished
# {'max_depth': 25, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 250}

# %%
CV_rfc.best_params_
# Out:
# {'max_depth': 25,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 250}

# %%
CV_rfc.best_score_
# Out:
# 0.997416446386487

# %%
CV_rfc.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_pred2 = pd.DataFrame( { 'actual':  y_test,
                                'predicted': CV_rfc.predict( X_test) } )

# %%
y_pred2
# Out:
#        actual  predicted
# 2862        1          1
# 13167       1          1
# 15722       1          1
# 21420       1          1
# 19507       1          1
# ...       ...        ...
# 10406       1          1
# 15431       1          1
# 18883       1          1
# 449         1          1
# 2264        1          1
#
# [7873 rows x 2 columns]

# %%
print(metrics.accuracy_score(y_pred2.actual, y_pred2.predicted))
print(metrics.roc_auc_score(y_pred2.actual, y_pred2.predicted))
# Out:
# 0.9913628858122698
# 0.9662509368450553

# %%
rftree_cm = metrics.confusion_matrix(y_pred2.predicted, y_pred2.actual, [1, 0])
sns.heatmap(rftree_cm,
            annot=True,
            cmap='Set3',
            fmt='.2f',
            )

plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# C:\Users\Mayank\Anaconda3\lib\site-packages\sklearn\utils\validation.py:71: FutureWarning: Pass labels=[1, 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Text(0.5, 12.5, 'Predicted label')

# %%
from sklearn.metrics import recall_score

recall_score(y_pred2.actual, y_pred2.predicted)
# Out:
# 0.9939991998933191

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y_test, CV_rfc.predict( X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       374
#            1       1.00      0.99      1.00      7499
#
#     accuracy                           0.99      7873
#    macro avg       0.94      0.97      0.95      7873
# weighted avg       0.99      0.99      0.99      7873

# %% [markdown]
# #### Gradient Boosting

# %%
import lightgbm as lgb
fit_params = {
    "early_stopping_rounds": 30,
    "eval_metric": 'auc',
    "eval_set": [(X_test, y_test)],
    'eval_names': ['valid'],
    #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
    'verbose': 100,
    'categorical_feature': 'auto'
}

from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
param_test = {
    'num_leaves': sp_randint(6, 50),
    'min_child_samples': sp_randint(100, 500),
    'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
    'subsample': sp_uniform(loc=0.2, scale=0.8),
    'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
    'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
    'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]
}

n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1,
                         random_state=42,
                         silent=True,
                         metric='None',
                         n_jobs=-1,
                         n_estimators=5000)
gs = RandomizedSearchCV(estimator=clf,
                        param_distributions=param_test,
                        n_iter=n_HP_points_to_test,
                        scoring='roc_auc',
                        cv=5,
                        refit=True,
                        random_state=42,
                        verbose=10,
                        n_jobs=-1)

gs.fit(X_res_train, y_res_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed: 25.5min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed: 27.5min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed: 29.3min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 31.7min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 33.5min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 35.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 38.4min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 41.2min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 44.1min finished
# RandomizedSearchCV(cv=5,
#                    estimator=LGBMClassifier(metric='None', n_estimators=5000,
#                                             random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000169C62A8EC8>,
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000169BCE6C648>,
#                                         'min_child_weight': [1e-05, 0.001, 0.01,
#                                                              0.1, 1, 10.0,
#                                                              100.0, 1000.0,
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000169BD78A508>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000169BCE6C8C8>},
#                    random_state=42, scoring='roc_auc', verbose=10)

# %%
print(gs.best_params_)
# Out:
# {'colsample_bytree': 0.48885215797203996, 'min_child_samples': 180, 'min_child_weight': 1e-05, 'num_leaves': 7, 'reg_alpha': 0.1, 'reg_lambda': 5, 'subsample': 0.2411830009999915}

# %%
gs.best_score_
# Out:
# 1.0

# %%
gs.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_pred3 = pd.DataFrame( { 'actual':  y_test,
                                'predicted': gs.predict( X_test) } )

# %%
print(metrics.accuracy_score(y_pred3.actual, y_pred3.predicted))
print(metrics.roc_auc_score(y_pred3.actual, y_pred3.predicted))
# Out:
# 0.9998729836148863
# 0.9999333244432591

# %%
rftree_cm = metrics.confusion_matrix(y_pred3.predicted, y_pred3.actual, [1, 0])
sns.heatmap(rftree_cm,
            annot=True,
            cmap='Set3',
            fmt='.2f',
            )

plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# C:\Users\Mayank\Anaconda3\lib\site-packages\sklearn\utils\validation.py:71: FutureWarning: Pass labels=[1, 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# Text(0.5, 12.5, 'Predicted label')

# %%
from sklearn.metrics import recall_score

recall_score(y_pred3.actual, y_pred3.predicted)
# Out:
# 0.9998666488865182

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y_test, gs.predict( X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       374
#            1       1.00      1.00      1.00      7499
#
#     accuracy                           1.00      7873
#    macro avg       1.00      1.00      1.00      7873
# weighted avg       1.00      1.00      1.00      7873

# %% [markdown]
# ### Predictions on the test data

# %%
test_cont
# Out:
#        X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  X_11      X_12  \
# 0        0   30   35    7    3    6    4    0    5     1   174  0.972236
# 1        0   44   44    1    3    7    1    4    6     1   316  0.000000
# 2        0   34   33    3    5    2    7    3    1     1   316  1.000000
# 3        7    3    2    3    5    9    8    0    5     1   174  1.000000
# 4        0    7    8    7    3    2    7    1    5     1   174  0.000000
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...       ...
# 15898    1   22   22    7    3   15   10    0    5     1   174  0.000000
# 15899    0   35   30    3    5    1    0    2    3     2     0  2.000000
# 15900    0   26   27    9    0    6    4    2    6     1     0  1.000000
# 15901    0   21   23    4    1    2    7    1    6     2   249  2.000000
# 15902    0    4    4    6    5    4    2    5    6     1   249  1.000000
#
#        X_13  X_14  X_15
# 0        72   119    23
# 1        12    29    34
# 2        72     0    34
# 3       112    87    34
# 4       112    93    43
# ...     ...   ...   ...
# 15898    72    29    43
# 15899    72    93    34
# 15900    72    62    34
# 15901    92    62    34
# 15902    72    29    34
#
# [15903 rows x 15 columns]

# %%
test_cont['MULTIPLE_OFFENSE']= gs.predict(test_cont)

# %%
test_cont['MULTIPLE_OFFENSE'].value_counts()
# Out:
# 1    15176
# 0      727
# Name: MULTIPLE_OFFENSE, dtype: int64

# %%
sample_submission = pd.concat([test_cat['INCIDENT_ID'], test_cont['MULTIPLE_OFFENSE']], axis = 1)

# %%
sample_submission.to_csv('C:\\Users\\Mayank\\Downloads\\Novartis-Data-Science-Challenge\\Dataset\\sample_submission.csv', index = False )

# %%
# Compute precision, recall, F-measure and support
from sklearn.metrics import classification_report
print(classification_report(y_test, gs.predict( X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       374
#            1       1.00      1.00      1.00      7499
#
#     accuracy                           1.00      7873
#    macro avg       1.00      1.00      1.00      7873
# weighted avg       1.00      1.00      1.00      7873

# %% [markdown]
# ### I got a Recall score of 0.99 and uploaded the sample submission file.

# %%
test_cont['MULTIPLE_OFFENSE'].value_counts(normalize=True)
# Out:
# 1    0.954285
# 0    0.045715
# Name: MULTIPLE_OFFENSE, dtype: float64
